# %%
pip install psycopg2-binary
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
hostname = 'localhost' # use config file
database = 'reto_2025'
username = 'postgres'
pwd = 'Xavavi04!'
port_id = 5432

# %%
INSERT INTO base 
(fraud_bool,income,name_email_similarity,prev_address_months_count,current_address_months_count,customer_age,days_since_request,intended_balcon_amount,payment_type,zip_count_4w,velocity_6h,velocity_24h,velocity_4w,bank_branch_count_8w,date_of_birth_distinct_emails_4w,employment_status,credit_risk_score,email_is_free,housing_status,phone_home_valid,phone_mobile_valid,bank_months_count,has_other_cards,proposed_credit_limit,foreign_request,source,session_length_in_minutes,device_os,keep_alive_session,device_distinct_emails_8w,device_fraud_count,month) VALUES (
0,
0.3,
0.986506310633034,
-1,
25,
40,
0.0067353870811739,
102.45371092469456,
AA,
1059,
13096.035018400871,
7850.955007125409,
6742.080561007602,
5,
5,
CB,
163,
1,
BC,
0,
1,
9,
0,1500.0,0,INTERNET,16.224843433978073,linux,1,1,0,0);

# %%
import psycopg2
import psycopg2.extras

# %%
conn = None
cur = None

try:
    conn = psycopg2.connect(
        host=hostname,
        dbname=database,
        user=username,
        password=pwd,
        port=port_id
    )

    cur = conn.cursor(cursor_factory=psycopg2.extras.DictCursor)

    for row in base_data

    conn.commit()

except Exception as error:
    print(f"Error: {error}")
    if conn:
        conn.rollback()
finally:
    if cur is not None:
        cur.close()
    if conn is not None:
        conn.close()

# %%
conn = None
cur = None

try:

    conn = psycopg2.connect(
        host = hostname,
        dbname = database,
        user = username,
        password = pwd,
        port = port_id
        
    )
    ### use cursor
    cur = conn.cursor()

    cur.execute('SELECT * FROM campo')
    for record in cur.fetchall():
        print(record)  # each record is a tuple
        print(record[1], record[2])
    

except Exception as error:
    print(error)
finally:
    if cur is not None:
        cur.close() # always close
    if conn is not None:
        conn.close() # always close
# Out:
# (1, 'El trigal', 150.0, 'Trigo', 3, 1)
# El trigal 150.0
# (2, 'La Esperanza', 350.0, 'Agave', 2, 3)
# La Esperanza 350.0
# (3, 'San Isidro', 200.0, 'Soya', 1, 4)
# San Isidro 200.0
# (4, 'La Cañada', 100.0, 'Caña de azúcar', 3, 2)
# La Cañada 100.0

# %%
conn = None
cur = None

try:

    conn = psycopg2.connect(
        host = hostname,
        dbname = database,
        user = username,
        password = pwd,
        port = port_id
        
    )
    ### use cursor
    cur = conn.cursor(cursor_factory=psycopg2.extras.DictCursor)

    cur.execute('SELECT * FROM campo')
    for record in cur.fetchall():
        print(record)  # each record is a tuple
        print(record[1], record[2])
        print(record['nombre'])

    
except Exception as error:
    print(error)
finally:
    if cur is not None:
        cur.close() # always close
    if conn is not None:
        conn.close() # always close
# Out:
# [1, 'El trigal', 150.0, 'Trigo', 3, 1]
# El trigal 150.0
# El trigal
# [2, 'La Esperanza', 350.0, 'Agave', 2, 3]
# La Esperanza 350.0
# La Esperanza
# [3, 'San Isidro', 200.0, 'Soya', 1, 4]
# San Isidro 200.0
# San Isidro
# [4, 'La Cañada', 100.0, 'Caña de azúcar', 3, 2]
# La Cañada 100.0
# La Cañada

# %%
conn = None
cur = None

try:
    conn = psycopg2.connect(
        host=hostname,
        dbname=database,
        user=username,
        password=pwd,
        port=port_id
    )

    cur = conn.cursor(cursor_factory=psycopg2.extras.DictCursor)

    cur.execute("""
        INSERT INTO cliente (nombre, contacto) VALUES 
        ('Agrosemillas del Centro S.A. de C.V.', 'contacto@agrosemillas.mx'),
        ('Hortalizas Don Juan SPR de RL', 'ventas@hortalizasdonjuan.com'),
        ('Grupo Sierra Produce', 'info@sierraproduce.mx'),
        ('Campos Verdes del Istmo', 'soporte@camposverdes-istmo.mx'),
        ('Agrícola El Porvenir SPR de RL', 'admin@agricolaporvenir.mx');
    """)

    cur.execute("""
        INSERT INTO ubicacion (nombre, lat, lon, direccion) VALUES 
        ('Culiacán, Sinaloa', 24.809064, -107.394005, 'Av. Álvaro Obregón 3500, Desarrollo Urbano 3 Ríos, 80000 Culiacán, Sin.'),
        ('Irapuato, Guanajuato', 20.676722, -101.356292, 'Blvd. Solidaridad 400, Irapuato, Gto.'),
        ('Los Mochis, Sinaloa', 25.792200, -108.993700, 'Carretera Internacional, Ejido 20 de Noviembre, Los Mochis, Sin.'),
        ('Mexicali, Baja California', 32.624538, -115.452263, 'Calzada Cetys 2650, Rivera, 21259 Mexicali, B.C.'),
        ('Tapachula, Chiapas', 14.900000, -92.266667, 'Av. Central Sur, Centro, 30700 Tapachula, Chis.');
    """)

    cur.execute("""
        INSERT INTO microorganismo (nombre_cientifico, nombre_comercial, dias_reproduccion) VALUES 
        ('Azospirillum brasilense', 'Azotop', 7),
        ('Trichoderma asperellum', 'TrichoPlus', 6),
        ('Bacillus velezensis', 'Serenade ASO', 5),
        ('Pseudomonas putida', 'Putida BioBoost', 8),
        ('Glomus mosseae', 'MycoApply EndoPrime', 12);
    """)

    conn.commit()

except Exception as error:
    print(f"Error: {error}")
    if conn:
        conn.rollback()
finally:
    if cur is not None:
        cur.close()
    if conn is not None:
        conn.close()

# %%
query = """
    INSERT INTO biofabrica_microorganismo (bf_micro_id ,biofabrica_id,microorganismo_id,fecha_inoc,volumen_actual)
    VALUES (%s, %s, %s, %s, %s)
"""

datos = {
    'bf_micro_id': [1, 2, 3, 4],
    'biofabrica_id': [4, 3, 1, 1],
    'microorganismo_id': [7, 6, 8, 10],
    'fecha_inoc': ['2025-07-01', '2025-07-25', '2025-07-07', '2025-07-11'],
    'volumen_actual': [400, 555, 300, 600]
}

df_datos = pd.DataFrame(datos)
cur.execute(query, df_datos)
conn.commit()

cur.close()
conn.close()

# %%
import pandas as pd
import numpy as np

# %%
from sqlalchemy import Column, Integer, String, Float, DateTime

# %%
conn = None
cur = None

try:
    conn = psycopg2.connect(
        host=hostname,
        dbname=database,
        user=username,
        password=pwd,
        port=port_id
    )

    cur = conn.cursor(cursor_factory=psycopg2.extras.DictCursor)
    query = """
    INSERT INTO biofabrica_microorganismo (bf_micro_id ,biofabrica_id,microorganismo_id,fecha_inoc,volumen_actual)
    VALUES ({}, {}, {}, {}, {})
    """
    
    datos = {
        'bf_micro_id': [7, 8, 9, 10],
        'biofabrica_id': [4, 3, 1, 1],
        'microorganismo_id': [7, 6, 8, 10],
        'fecha_inoc': ['2025-07-01', '2025-07-25', '2025-07-07', '2025-07-11'],
        'volumen_actual': [400, 555, 300, 600]
    }
    
    df_datos = pd.DataFrame(datos)
    
    for n, fila in df_datos.iterrows():
        fila_convertida = [int(x) if isinstance(x, (np.integer, np.int64)) else x for x in df_datos.iloc[n].tolist()]
        cur.execute(query.format(fila_convertida[0],fila_convertida[1],fila_convertida[2],"'"+fila_convertida[3]+"'",fila_convertida[4]))
    
    conn.commit()
except Exception as error:
    print(f"Error: {error}")
    if conn:
        conn.rollback()
finally:
    if cur is not None:
        cur.close()
    if conn is not None:
        conn.close()

# %%
   query = """
    INSERT INTO biofabrica_microorganismo (bf_micro_id ,biofabrica_id,microorganismo_id,fecha_inoc,volumen_actual)
    VALUES ({}, {}, {}, {}, {})
    """

# %%
conn = None
cur = None

try:
    conn = psycopg2.connect(
        host=hostname,
        dbname=database,
        user=username,
        password=pwd,
        port=port_id
    )

    cur = conn.cursor(cursor_factory=psycopg2.extras.DictCursor)
    query = """
    INSERT INTO campo (campo_id, nombre, superficie_ha, cultivo, cliente_id, ubicacion_id)
    VALUES ({}, {}, {}, {}, {}, {})
    """
    
    datos = {
        'campo_id': [6, 7, 8, 9],
        'nombre': ['Campo 6', 'Campo 7', 'Campo 8', 'Campo 9'],
        'superficie_ha': [400, 555, 300, 600],
        'cultivo': ['Soya', 'Papas', 'Jitomate', 'Mango'],
        'cliente_id': [4, 5, 3, 6],
        'ubicacion_id': [4, 5, 3, 6]
    }
    
    
    df_datos = pd.DataFrame(datos)
    
    for n, fila in df_datos.iterrows():
        fila_convertida = [int(x) if isinstance(x, (np.integer, np.int64)) else x for x in df_datos.iloc[n].tolist()]
        cur.execute(query.format(fila_convertida[0],"'"+fila_convertida[1]+"'",fila_convertida[2],"'"+fila_convertida[3]+"'",fila_convertida[4],fila_convertida[5]))


    conn.commit()
except Exception as error:
    print(f"Error: {error}")
    if conn:
        conn.rollback()
finally:
    if cur is not None:
        cur.close()
    if conn is not None:
        conn.close()

# %%
datos_alerta = {
    "biofabrica_id": [1, 2, 3, 1],
    "tipo": ["oxígeno", "temperatura", "ph", "nutriente"],
    "mensaje": [
        "Nivel de oxígeno bajo",
        "Temperatura por encima del umbral",
        "pH fuera de rango",
        "Baja concentración de nutriente A"
    ],
    "atendida": [True, False, False, True]
}

df_alerta = pd.DataFrame(datos_alerta)

sentencia = """
    INSERT INTO alerta (biofabrica_id, tipo, mensaje, atendida)
    VALUES (%s, %s, %s, %s)
"""
parametros = [
    (
        int(fila[0]) if isinstance(fila[0], (np.integer, np.int64)) else fila[0],
        fila[1],
        fila[2],
        fila[3]
    )
    for fila in df_alerta.itertuples(index=False, name=None)
]

try:
    cursor.executemany(sentencia, parametros)
    conexion.commit()

# %%
conn = None
cur = None

try:
    conn = psycopg2.connect(
        host=hostname,
        dbname=database,
        user=username,
        password=pwd,
        port=port_id
    )

    cur = conn.cursor(cursor_factory=psycopg2.extras.DictCursor)
    datos_alerta = {
    "biofabrica_id": [1, 2, 3, 1],
    "tipo": ["oxígeno", "temperatura", "ph", "nutriente"],
    "mensaje": [
        "Nivel de oxígeno bajo",
        "Temperatura por encima del umbral",
        "pH fuera de rango",
        "Baja concentración de nutriente A"
    ],
    "atendida": [True, False, False, True]
    }

    df_alerta = pd.DataFrame(datos_alerta)

    sentencia = """
    INSERT INTO alerta (biofabrica_id, tipo, mensaje, atendida)
    VALUES (%s, %s, %s, %s)
    """
    parametros = [
    (
        int(fila[0]) if isinstance(fila[0], (np.integer, np.int64)) else fila[0],
        fila[1],
        fila[2],
        fila[3]
    )
    for fila in df_alerta.itertuples(index=False, name=None)
    ]

    cur.executemany(sentencia, parametros)
    conn.commit()
except Exception as error:
    print(f"Error: {error}")
    if conn:
        conn.rollback()
finally:
    if cur is not None:
        cur.close()
    if conn is not None:
        conn.close()

# %%
my_list = [1, np.int64(2), 3, np.int64(4), 5]
converted_list = [int(item) if isinstance(item, np.int64) else item for item in my_list]
print(converted_list)
# Out:
# [1, 2, 3, 4, 5]

# %%
query.format([1,2,3,4,5])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 query.format([1,2,3,4,5])
#
# IndexError: Replacement index 1 out of range for positional args tuple

# %%
from datetime import date

conn = None
cur = None

try:
    conn = psycopg2.connect(
        host=hostname,
        dbname=database,
        user=username,
        password=pwd,
        port=port_id
    )

    cur = conn.cursor(cursor_factory=psycopg2.extras.DictCursor)
    datos_aplicacion = {
    "campo_id": [1, 2, 3, 1],
    "microorganismo_id": [1, 2, 1, 3],
    "fecha": [date(2025, 7, 1), date(2025, 7, 3), date(2025, 7, 5), date(2025, 7, 7)],
    "dosis_litros": [1.0, 1.5, 0.8, 2.0],
    "metodo": ["irrigacion", "aspersión", "dron", "goteo"]
    }

    df_aplicacion = pd.DataFrame(datos_aplicacion)

    cursor = conn.cursor()

    sentencia = """
    INSERT INTO aplicacion (campo_id, microorganismo_id, fecha, dosis_litros, metodo)
    VALUES (%s, %s, %s, %s, %s)
    """

    parametros = [
    (
        int(fila[0]) if isinstance(fila[0], (np.integer, np.int64)) else fila[0],
        int(fila[1]) if isinstance(fila[1], (np.integer, np.int64)) else fila[1],
        fila[2],
        float(fila[3]),
        fila[4]
    )
    for fila in df_aplicacion.itertuples(index=False, name=None)
    ]

    cur.executemany(sentencia, parametros)
    conn.commit()

except Exception as error:
    print(f"Error: {error}")
    if conn:
        conn.rollback()
finally:
    if cur is not None:
        cur.close()
    if conn is not None:
        conn.close()

# %%
from datetime import date

conn = None
cur = None

try:
    conn = psycopg2.connect(
        host=hostname,
        dbname=database,
        user=username,
        password=pwd,
        port=port_id
    )

    cur = conn.cursor(cursor_factory=psycopg2.extras.DictCursor)
    datos_sensor = {
        "sensor_id": [5, 4, 6, 7],
        "tipo": ["Uno", "Dos", "Tres", "Cuatro"],
        "unidad": ["ppm", "°C", "%", "lux"],
        "biofabrica_id": [1, 1, 2, 2],
        "habilitado": [True, True, False, True]
    }
    
    df_sensor = pd.DataFrame(datos_sensor)
        
    sentencia = """
        INSERT INTO sensor (sensor_id, tipo, unidad, biofabrica_id, habilitado)
        VALUES (%s, %s, %s, %s, %s)
    """
    
    parametros = [
        (
            int(fila[0]) if isinstance(fila[0], (np.integer, np.int64)) else fila[0],
            fila[1],
            fila[2],
            int(fila[3]) if isinstance(fila[3], (np.integer, np.int64)) else fila[3],
            fila[4]
        )
        for fila in df_sensor.itertuples(index=False, name=None)
    ]
    
    cur.executemany(sentencia, parametros)
    conn.commit()

except Exception as error:
    print(f"Error: {error}")
    if conn:
        conn.rollback()
finally:
    if cur is not None:
        cur.close()
    if conn is not None:
        conn.close()

# %%
from datetime import datetime

conn = None
cur = None

try:
    conn = psycopg2.connect(
        host=hostname,
        dbname=database,
        user=username,
        password=pwd,
        port=port_id
    )

    cur = conn.cursor(cursor_factory=psycopg2.extras.DictCursor)
    datos_lectura = {
    "lectura_id": [4, 5, 6, 7],
    "sensor_id": [1, 2, 3, 1],
    "fecha_hora": [
        datetime(2025, 7, 26, 12, 0),
        datetime(2025, 7, 26, 12, 5),
        datetime(2025, 7, 26, 12, 10),
        datetime(2025, 7, 26, 12, 15)
    ],
    "valor": [10.5, 20.5, 30.9, 15.2]}

    df_lectura = pd.DataFrame(datos_lectura)
    
    sentencia = """
        INSERT INTO lectura_sensor (lectura_id, sensor_id, fecha_hora, valor)
        VALUES (%s, %s, %s, %s)
    """
    
    parametros = [
        (
            int(fila[0]) if isinstance(fila[0], (np.integer, np.int64)) else fila[0],
            int(fila[1]) if isinstance(fila[1], (np.integer, np.int64)) else fila[1],
            fila[2],
            float(fila[3])
        )
        for fila in df_lectura.itertuples(index=False, name=None)
    ]


    cur.executemany(sentencia, parametros)
    conn.commit()

except Exception as error:
    print(f"Error: {error}")
    if conn:
        conn.rollback()
finally:
    if cur is not None:
        cur.close()
    if conn is not None:
        conn.close()

# %%
columns = ['biofabrica_id', 'codigo', 'capacidad_l', 'nivel_actual', 'cliente_id', 'ubicacion_id']

query = """    INSERT INTO biofabrica (biofabrica_id, codigo, capacidad_l, nivel_actual, cliente_id, ubicacion_id)
    VALUES (%s, %s, %s, %s, %s, %s)
"""

datos = {
    'biofabrica_id': [5,6,7,8,9],
    'codigo': ['BIOF005', 'BIOF006', 'BIOF007', 'BIOF008', 'BIOF009'],
    'capacidad_l': [1800,1000,1600,1400,2000],
    'nivel_actual': [900, 250, 1200, 600, 1950],
    'cliente_id': [5, 2, 1, 3, 4],
    'ubicacion_id': [2, 3, 1, 2, 3]
}

try:
    conn = psycopg2.connect(
        host=hostname,
        dbname=database,
        user=username,
        password=pwd,
        port=port_id
    )

    cur = conn.cursor()

    for i in range(len(datos['biofabrica_id'])):
        values = tuple(datos[col][i] for col in columns)
        cur.execute(query, values)

    conn.commit()

# %%
from datetime import datetime

conn = None
cur = None

try:
    conn = psycopg2.connect(
        host=hostname,
        dbname=database,
        user=username,
        password=pwd,
        port=port_id
    )

    cur = conn.cursor(cursor_factory=psycopg2.extras.DictCursor)
    columns = ['biofabrica_id', 'codigo', 'capacidad_l', 'nivel_actual', 'cliente_id', 'ubicacion_id']

    query = """    INSERT INTO biofabrica (biofabrica_id, codigo, capacidad_l, nivel_actual, cliente_id, ubicacion_id)
    VALUES (%s, %s, %s, %s, %s, %s)
    """

    datos = {
    'biofabrica_id': [5,6,7,8,9],
    'codigo': ['BIOF005', 'BIOF006', 'BIOF007', 'BIOF008', 'BIOF009'],
    'capacidad_l': [1800,1000,1600,1400,2000],
    'nivel_actual': [900, 250, 1200, 600, 1950],
    'cliente_id': [5, 2, 1, 3, 4],
    'ubicacion_id': [2, 3, 1, 2, 3]
    }

    for i in range(len(datos['biofabrica_id'])):
        values = tuple(datos[col][i] for col in columns)
        cur.execute(query, values)

    conn.commit()

except Exception as error:
    print(f"Error: {error}")
    if conn:
        conn.rollback()
finally:
    if cur is not None:
        cur.close()
    if conn is not None:
        conn.close()
